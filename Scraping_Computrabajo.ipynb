# %% [markdown]
# <a href="https://colab.research.google.com/github/naty0611/Entregas/blob/main/Scraping_Computrabajo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# google-colab-selenium es un wrapper para facilitar usar Selenium en Google Colab
# %pip install -q google-colab-selenium

# Importacion de librerias necesarias
import google_colab_selenium as gs  # librería que permite lanzar Chrome en Google Colab
from selenium.webdriver.common.by import By # localiza elementos por selectores (CSS, XPATH, etc.)
from selenium.webdriver.support.ui import WebDriverWait  # para aplicar esperas explícitas
from selenium.webdriver.support import expected_conditions as EC  # condiciones que usarán las esperas
import time, os, random  # librerías estándar para tiempos, carpetas y pausas aleatorias
import pandas as pd  # Crear y manejar DataFrames con los resultados
from google.colab import data_table   # Muestra tablas interactivas en Colab

# %%
# FUNCIONES AUXILIARES

def first_text(elem, selectors):
    """
    Devuelve el primer texto no vacío encontrado probando varios selectores CSS.
    - elem puede ser el driver o un WebElement.
    - selectors es una lista de strings CSS.
    """
    for sel in selectors:   # recorre cada selector de la lista
        try:
            found = elem.find_elements(By.CSS_SELECTOR, sel)  # busca elementos que coincidan
        except Exception:  # si falla el selector, no rompe el programa
            found = []
        for f in found:   # recorre cada elemento encontrado
            txt = f.text.strip()  # extrae y limpia el texto
            if txt:  # si no está vacío
                return txt  # lo devuelve inmediatamente el texto encontrado
    return ""  # si ninguno funcionó, devuelve string vacío


def find_requirements(driver):
    """
    Heurística para encontrar la lista de requisitos de la oferta.
    Busca en distintos lugares del HTML, probando en orden de prioridad:
    1. Lista <ul> con clase típica de requisitos
    2. Encabezado 'Requisitos' seguido de una lista
    3. Fallback: cualquier <ul> con >=2 <li> y palabras clave
    """
    # Caso típico: <ul> con clase específica
    try:
        lis = driver.find_elements(By.CSS_SELECTOR, "ul.fs16.disc.mbB li")  # busca los <li> dentro de ese <ul>
        if lis:   # si encontró algo
            return "; ".join([li.text.strip() for li in lis if li.text.strip()])  # une todo en un string
    except:
        pass

    # caso encabezado 'Requisitos' seguido de UL
    try:
        xpath = ("//h3[contains(translate(normalize-space(.),'REQUISITOS','requisitos'),'requisitos')]/"
                 "following-sibling::ul[1]/li | "
                 "//h4[contains(translate(normalize-space(.),'REQUISITOS','requisitos'),'requisitos')]/"
                 "following-sibling::ul[1]/li")
        lis = driver.find_elements(By.XPATH, xpath)  # busca los <li> justo después de un título con 'Requisitos'
        if lis:
            return "; ".join([li.text.strip() for li in lis if li.text.strip()])
    except:
        pass

    # Caso Fallback: cualquier lista <ul> con >=2 <li> y palabras clave
    try:
        uls = driver.find_elements(By.TAG_NAME, "ul")   # busca todas las listas <ul>
        for ul in uls:
            lis = ul.find_elements(By.TAG_NAME, "li")   # toma los <li> de esa lista
            if len(lis) >= 2:  # si hay al menos 2 elementos
                texts = [li.text.strip() for li in lis if li.text.strip()]  # extrae sus textos
                snippet = " ".join(texts[:3]).lower()  # junta los primeros 3 para analizarlos
                if any(k in snippet for k in ("experien", "conocim", "requisit", "competenc", "habilid")):
                    return "; ".join(texts)  # si hay palabras clave, devuelve la lista completa
    except:
        pass

    return ""

# %%
# CONFIGURACIÓN INICIAL

driver = gs.Chrome()   # inicializa navegador en Colab
base_url = "https://co.computrabajo.com/trabajo-de-analista-de-datos?p="  # URL base con pagina requerida
results = []           # lista donde se guardarán todas las ofertas
max_pages = 50         # número máximo de páginas a recorrer para obtener 1_000 ofertas
debug_folder = "/content/debug_html"   # carpeta donde se guardarán páginas con problemas
os.makedirs(debug_folder, exist_ok=True)  # crea la carpeta si no existe
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="8c63daaa-8923-4b8e-b335-4490e191a15f-circle"></div>
#                 <div class="spinner-text" id="8c63daaa-8923-4b8e-b335-4490e191a15f-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>

# %%
# BUCLE PARA RECORRER LAS 50 PAGINAS QUE NECESITAMOS

for page in range(1, max_pages + 1):  # recorre páginas desde la 1 la 50+1
    print(f"Extrayendo página {page}...")  # muestra progreso de la extracción
    driver.get(base_url + str(page))  # abre la URL de la página

    # Espera a que carguen las tarjetas
    try:
        WebDriverWait(driver, 12).until(
            EC.presence_of_all_elements_located((By.CSS_SELECTOR, "article.box_offer"))
        )   # espera máximo 12s a que aparezcan las ofertas
    except Exception:   # si no encuentra nada
        print(f"No se encontraron ofertas en la página {page}. Terminando scraping.")
        break  # Rompe el ciclo

    ofertas = driver.find_elements(By.CSS_SELECTOR, "article.box_offer")  # obtiene todas las tarjetas de la página
    if not ofertas:   # si la lista está vacía, termina el bucle
        break

    # Recorrer cada tarjeta de oferta
    for oferta_idx, oferta in enumerate(ofertas):   # recorre cada tarjeta de la página
        # Scroll para asegurar visibilidad
        try:
            driver.execute_script("arguments[0].scrollIntoView(true);", oferta)
        except:
            pass

        # Extraer título y link
        title = first_text(oferta, ["h2.fs18 a", "h2.fs18", "h2"])  # obtiene texto del título
        try:
            titulo_el = oferta.find_element(By.CSS_SELECTOR, "h2.fs18 a")  # busca el link del títul
            link = titulo_el.get_attribute("href")  # extraer el enlace del titulo
        except:
            try:
                a = oferta.find_element(By.TAG_NAME, "a")  # si no está en el <h2>, toma el primer <a>
                link = a.get_attribute("href")
            except:
                link = ""  # si no encontró nada, queda vacío

        # Empresa, ubicación y fecha
        company = first_text(oferta, ["a.fc_base.t_ellipsis", "div.company", "span.company"])
        location = first_text(oferta, ["span.mr10", "span.location"])
        date = first_text(oferta, ["p.fs13.fc_aux.mt15", "p.date"])

        # Datos de la tarjeta (salario y modalidad preliminar)
        detail_card_text = first_text(oferta, [
            "p.fs13.mt10 span.fc_base",
            "span.dIB.mr10:nth-child(1)",
            "p.fs13.mt10"
        ])

        salary_card = "No especificado"  # valor por defecto
        modality_card = ""   # valor por defecto

        # Detecta si el texto contiene salario
        if "$" in detail_card_text or "A convenir" in detail_card_text or "Mensual" in detail_card_text:
            salary_card = detail_card_text

        # Detecta modalidad si está en tarjeta
        if "Remoto" in detail_card_text or "Presencial" in detail_card_text or "Híbrido" in detail_card_text:
            if "Presencial" in detail_card_text: modality_card = "Presencial"
            elif "Remoto" in detail_card_text: modality_card = "Remoto"
            elif "Híbrido" in detail_card_text: modality_card = "Híbrido"

        # Inicializamos variables finales
        salary = salary_card
        description = ""
        requirements = ""
        modality = modality_card or "PENDIENTE_DE_CONFIRMACION"

        # Abrir detalle si existe link
        if link:
            original_handle = driver.current_window_handle  # guarda pestaña actual
            driver.execute_script("window.open('');")  # abre nueva pestaña vacía
            driver.switch_to.window(driver.window_handles[-1])  # cambia a la nueva pestaña
            driver.get(link)   # abre el link de la oferta

            # Espera a que cargue la página de detalle
            try:
                WebDriverWait(driver, 12).until(
                    EC.presence_of_element_located((By.CSS_SELECTOR, "div.box_detail"))
                )
            except:
                WebDriverWait(driver, 8).until(
                    EC.presence_of_element_located((By.TAG_NAME, "body"))
                )

            # Extraer salario detallado
            salary_detail_text = first_text(driver, [
                "div.box_detail p.fs16.fc_base",
                "div.box_detail span.fc_base",
                "div.box_detail span.dIB.mr10",
                "p.salary", "span.salary"
            ])
            if "$" in salary_detail_text or "A convenir" in salary_detail_text:
                salary = salary_detail_text.split(" Contrato")[0].strip()

            # Extraer Descripción
            description = first_text(driver, [
                "div.box_detail > div.mbB",
                "div.box_detail div.mbB",
                "div.offer-description",
                "div[itemprop='description']",
                "div.description"
            ])

            # Extraer Requisitos
            requirements = find_requirements(driver)

            # Confirmar modalidad (si no estaba en tarjeta)
            if modality == "PENDIENTE_DE_CONFIRMACION":
                modality_detail_text = first_text(driver, [
                    "div.box_detail p.fs13 span.fc_base",
                    "div.box_detail span.dIB.mr10",
                ])
                clean_modality = ""
                if "Presencial" in modality_detail_text: clean_modality = "Presencial"
                elif "Remoto" in modality_detail_text: clean_modality = "Remoto"
                elif "Híbrido" in modality_detail_text: clean_modality = "Híbrido"
                modality = clean_modality or "Presencial"

            # Guardar HTML si faltan datos para depuración
            if not description or not requirements or salary in ("No especificado", ""):
                fname = os.path.join(debug_folder, f"debug_page_{page}_offer_{oferta_idx}.html")
                with open(fname, "w", encoding="utf-8") as f:
                    f.write(driver.page_source)
                print("Guardé HTML de depuración en:", fname)

            # Cerrar pestaña detalle y volver a la lista
            driver.close()
            driver.switch_to.window(original_handle)
        else:
            if modality not in ("Remoto", "Híbrido"): # Si no había link, asigna presencial por defecto salvo que diga remoto/híbrido
                modality = "Presencial"

        # Guardar la oferta en la lista de resultados
        results.append({
            "Titulo": title,
            "Empresa": company,
            "Ubicacion": location,
            "Fecha": date,
            "Modalidad": modality,
            "Salario": salary,
            "Requerimientos": requirements,
            "Descripcion": description,
            "Link": link
        })

    # Pausa aleatoria para evitar bloqueo
    time.sleep(random.uniform(1.0, 2.5))


# CERRAR DRIVER Y EXPORTAR

driver.quit()  # cierra el navegador
data_table.enable_dataframe_formatter()  # habilita visualización interactiva en Colab

df = pd.DataFrame(results)  # crea un DataFrame con los resultados
df.to_csv("computrabajo_ofertas_final.csv", index=False, encoding="utf-8-sig")  # exporta a CSV

print("Scraping completado. Registros extraídos:", len(df))   # imprime número de registros
df  # muestra el DF
# Out:
# Extrayendo página 1...
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_1_offer_19.html
# Extrayendo página 2...
# Guardé HTML de depuración en: /content/debug_html/debug_page_2_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_2_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_2_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_2_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_2_offer_18.html
# Extrayendo página 3...
# Guardé HTML de depuración en: /content/debug_html/debug_page_3_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_3_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_3_offer_19.html
# Extrayendo página 4...
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_4_offer_19.html
# Extrayendo página 5...
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_5_offer_19.html
# Extrayendo página 6...
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_6_offer_16.html
# Extrayendo página 7...
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_7_offer_19.html
# Extrayendo página 8...
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_8_offer_19.html
# Extrayendo página 9...
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_9_offer_19.html
# Extrayendo página 10...
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_10_offer_16.html
# Extrayendo página 11...
# Guardé HTML de depuración en: /content/debug_html/debug_page_11_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_11_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_11_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_11_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_11_offer_19.html
# Extrayendo página 12...
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_12_offer_19.html
# Extrayendo página 13...
# Guardé HTML de depuración en: /content/debug_html/debug_page_13_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_13_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_13_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_13_offer_18.html
# Extrayendo página 14...
# Guardé HTML de depuración en: /content/debug_html/debug_page_14_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_14_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_14_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_14_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_14_offer_9.html
# Extrayendo página 15...
# Guardé HTML de depuración en: /content/debug_html/debug_page_15_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_15_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_15_offer_18.html
# Extrayendo página 16...
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_16_offer_19.html
# Extrayendo página 17...
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_17_offer_19.html
# Extrayendo página 18...
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_18_offer_19.html
# Extrayendo página 19...
# Guardé HTML de depuración en: /content/debug_html/debug_page_19_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_19_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_19_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_19_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_19_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_19_offer_17.html
# Extrayendo página 20...
# Guardé HTML de depuración en: /content/debug_html/debug_page_20_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_20_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_20_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_20_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_20_offer_16.html
# Extrayendo página 21...
# Guardé HTML de depuración en: /content/debug_html/debug_page_21_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_21_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_21_offer_3.html
# Extrayendo página 22...
# Guardé HTML de depuración en: /content/debug_html/debug_page_22_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_22_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_22_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_22_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_22_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_22_offer_19.html
# Extrayendo página 23...
# Guardé HTML de depuración en: /content/debug_html/debug_page_23_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_23_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_23_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_23_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_23_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_23_offer_13.html
# Extrayendo página 24...
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_24_offer_14.html
# Extrayendo página 25...
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_25_offer_19.html
# Extrayendo página 26...
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_26_offer_19.html
# Extrayendo página 27...
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_27_offer_19.html
# Extrayendo página 28...
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_28_offer_18.html
# Extrayendo página 29...
# Guardé HTML de depuración en: /content/debug_html/debug_page_29_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_29_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_29_offer_17.html
# Extrayendo página 30...
# Guardé HTML de depuración en: /content/debug_html/debug_page_30_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_30_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_30_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_30_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_30_offer_17.html
# Extrayendo página 31...
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_31_offer_18.html
# Extrayendo página 32...
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_32_offer_19.html
# Extrayendo página 33...
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_33_offer_19.html
# Extrayendo página 34...
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_34_offer_19.html
# Extrayendo página 35...
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_35_offer_19.html
# Extrayendo página 36...
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_36_offer_19.html
# Extrayendo página 37...
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_37_offer_18.html
# Extrayendo página 38...
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_38_offer_19.html
# Extrayendo página 39...
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_39_offer_16.html
# Extrayendo página 40...
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_40_offer_18.html
# Extrayendo página 41...
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_41_offer_19.html
# Extrayendo página 42...
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_42_offer_14.html
# Extrayendo página 43...
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_43_offer_19.html
# Extrayendo página 44...
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_44_offer_19.html
# Extrayendo página 45...
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_7.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_45_offer_19.html
# Extrayendo página 46...
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_0.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_1.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_3.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_9.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_16.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_17.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_46_offer_18.html
# Extrayendo página 47...
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_5.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_6.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_47_offer_19.html
# Extrayendo página 48...
# Guardé HTML de depuración en: /content/debug_html/debug_page_48_offer_8.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_48_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_48_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_48_offer_13.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_48_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_48_offer_15.html
# Extrayendo página 49...
# Guardé HTML de depuración en: /content/debug_html/debug_page_49_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_49_offer_4.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_49_offer_11.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_49_offer_12.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_49_offer_15.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_49_offer_19.html
# Extrayendo página 50...
# Guardé HTML de depuración en: /content/debug_html/debug_page_50_offer_2.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_50_offer_10.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_50_offer_14.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_50_offer_18.html
# Guardé HTML de depuración en: /content/debug_html/debug_page_50_offer_19.html
# Scraping completado. Registros extraídos: 1000
#                                                 Titulo  \
# 0                                         Datamarshall
# 1    Analista de gestion conocimiento en nomina, fi...
# 2                            Analista de base de datos
# 3                        Analista de datos comerciales
# 4                                         Data Analyst
# ..                                                 ...
# 995               Asesor Comercial Bancario / Libranza
# 996                                 Asesor/a Comercial
# 997         Consultor/a de belleza asesor/a perfumista
# 998  Asesor servicio al cliente, contratación estab...
# 999  Recepción de llamadas telefónicas servicio al ...
#
#                                        Empresa                   Ubicacion  \
# 0                      COVISIAN COLOMBIA S.A.S                         4,1
# 1                                                  Barranquilla, Atlántico
# 2                                          TCC                         4,5
# 3     RECORDAR PREVISION EXEQUIAL TOTAL S. A.S  Bogotá, D.C., Bogotá, D.C.
# 4                                      TALENTO         Medellín, Antioquia
# ..                                         ...                         ...
# 995                                                    Medellín, Antioquia
# 996  Agencia de Empleo de Comfenalco Antioquia         Medellín, Antioquia
# 997                  S&A Servicios y Asesorias                         4,5
# 998                                ATENTO S.A.                         4,3
# 999                                ATENTO S.A.                         4,3
#
#             Fecha   Modalidad                                Salario  \
# 0     Hace 1 hora  Presencial               $ 3.900.000,00 (Mensual)
# 1    Hace 5 horas  Presencial               $ 2.200.000,00 (Mensual)
# 2    Hace 5 horas  Presencial               $ 3.886.000,00 (Mensual)
# 3    Hace 5 horas  Presencial                        No especificado
# 4    Hace 7 horas  Presencial                        No especificado
# ..            ...         ...                                    ...
# 995   Hace 2 días  Presencial  $ 1.423.500,00 (Mensual) + Comisiones
# 996   Hace 2 días  Presencial               $ 2.000.000,00 (Mensual)
# 997   Hace 2 días  Presencial               $ 2.000.000,00 (Mensual)
# 998   Hace 2 días  Presencial                        No especificado
# 999   Hace 2 días  Presencial                        No especificado
#
#                                         Requerimientos  \
# 0    Educación mínima: Universidad / Carrera Profes...
# 1    Educación mínima: Universidad / Carrera Profes...
# 2    Educación mínima: Universidad / Carrera Profes...
# 3    Educación mínima: Universidad / Carrera Profes...
# 4    Educación mínima: Universidad / Carrera técnic...
# ..                                                 ...
# 995  Educación mínima: Universidad / Carrera técnic...
# 996  Educación mínima: Universidad / Carrera Profes...
# 997  Educación mínima: Bachillerato / Educación Med...
# 998  Educación mínima: Bachillerato / Educación Med...
# 999  Educación mínima: Bachillerato / Educación Med...
#
#                                            Descripcion  \
# 0    $ 3.900.000,00 (Mensual) Contrato de Obra o la...
# 1    $ 2.200.000,00 (Mensual) Contrato a término in...
# 2    $ 3.886.000,00 (Mensual) Contrato a término in...
# 3    A convenir Contrato a término indefinido Tiemp...
# 4    A convenir Contrato a término indefinido Tiemp...
# ..                                                 ...
# 995  $ 1.423.500,00 (Mensual) + Comisiones Contrato...
# 996  $ 2.000.000,00 (Mensual) Contrato a término fi...
# 997  $ 2.000.000,00 (Mensual) Contrato de Obra o la...
# 998  A convenir Contrato a término indefinido Tiemp...
# 999  A convenir Contrato a término indefinido Tiemp...
#
#                                                   Link
# 0    https://co.computrabajo.com/ofertas-de-trabajo...
# 1    https://co.computrabajo.com/ofertas-de-trabajo...
# 2    https://co.computrabajo.com/ofertas-de-trabajo...
# 3    https://co.computrabajo.com/ofertas-de-trabajo...
# 4    https://co.computrabajo.com/ofertas-de-trabajo...
# ..                                                 ...
# 995  https://co.computrabajo.com/ofertas-de-trabajo...
# 996  https://co.computrabajo.com/ofertas-de-trabajo...
# 997  https://co.computrabajo.com/ofertas-de-trabajo...
# 998  https://co.computrabajo.com/ofertas-de-trabajo...
# 999  https://co.computrabajo.com/ofertas-de-trabajo...
#
# [1000 rows x 9 columns]
